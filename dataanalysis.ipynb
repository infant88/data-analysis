# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Sales data Tablue.xlsx")

# %%
df
# Out:
#                         Region               Country   Item_Type  \
# 0             Central America   Antigua and Barbuda    Baby Food
# 1             Central America                 Panama      Snacks
# 2                       Europe        Czech Republic   Beverages
# 3                         Asia           North Korea      Cereal
# 4                         Asia             Sri Lanka      Snacks
# ...                        ...                   ...         ...
# 4995         Australia/Oceania           New Zealand  Vegetables
# 4996  Middle East/North Africa            Azerbaijan      Snacks
# 4997                      Asia               Myanmar   Baby Food
# 4998                    Europe               Finland     Clothes
# 4999        Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority           Order_Date  Year   Order_ID  \
# 0           Online              M           12/20/2013  2013  957081544
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 547.0+ KB

# %%
# to find the null value in the column
df.isnull().sum()
# Out:
# Region               0
# Country              0
# Item_Type            0
# Sales_Channel        0
# Order_Priority       0
# Order_Date           0
# Year                 0
# Order_ID             0
# Ship_Date            0
# Units_Sold           0
# Unit_SellingPrice    0
# Unit_MakingCost      0
# unit_per Profit      0
# Total profit         0
# dtype: int64

# %%
# value count of any column
df["Country"].value_counts().tail(10)
# Out:
# Country
# Trinidad and Tobago    19
# Afghanistan            19
# Syria                  19
# Bahrain                18
# Croatia                18
# Dominica               18
# Angola                 16
# Mongolia               15
# Cape Verde             14
# Monaco                 13
# Name: count, dtype: int64

# %%
df["Country"].value_counts().head(10)
# Out:
# Country
# San Marino                  40
# Andorra                     40
# Ghana                       38
# Mauritius                   38
# United States of America    38
# Tonga                       37
# South Korea                 36
# Haiti                       36
# Somalia                     36
# Grenada                     36
# Name: count, dtype: int64

# %%
df["Country"].value_counts().head(10).plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df["Country"].value_counts().tail(10).plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df["Unit_SellingPrice"].describe()
# Out:
# count    5000.000000
# mean      265.745564
# std       218.716695
# min         9.330000
# 25%        81.730000
# 50%       154.060000
# 75%       437.200000
# max       668.270000
# Name: Unit_SellingPrice, dtype: float64

# %%
df["Unit_SellingPrice"].median()
# Out:
# 154.06

# %%
df["Country"].value_counts()
# Out:
# Country
# San Marino                  40
# Andorra                     40
# Ghana                       38
# Mauritius                   38
# United States of America    38
#                             ..
# Dominica                    18
# Angola                      16
# Mongolia                    15
# Cape Verde                  14
# Monaco                      13
# Name: count, Length: 185, dtype: int64

# %%
plt.figure(figsize=(10,5))
df.groupby("Country")["Unit_SellingPrice"].sum().head(20).plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %%
plt.figure(figsize=(10,5))
df.groupby("Country")["Unit_SellingPrice"].sum().tail(20).plot.pie()
# Out:
# <Axes: ylabel='Unit_SellingPrice'>

# %%
df["Order_Priority"].value_counts()
df.groupby("Order_Priority")["Units_Sold"].sum().plot.barh()
# Out:
# <Axes: ylabel='Order_Priority'>

# %%
df["Item_Type"].value_counts()
df.groupby("Item_Type")["Units_Sold"].sum().plot.bar()
plt.plot(df.groupby("Item_Type")["Units_Sold"].sum(),"bo--")

# %%
df["Year"].value_counts()
df.groupby("Year")["Units_Sold"].sum().plot.pie()
# Out:
# <Axes: ylabel='Units_Sold'>

# %%
plt.figure(figsize = (10,5))
df["Year"].value_counts()
df.groupby("Year")["unit_per Profit"].sum().plot.pie()
df.groupby("Year")["Unit_MakingCost"].sum().plot.pie()
# Out:
# <Axes: ylabel='Unit_MakingCost'>

# %%
df.groupby("Year")[["Unit_MakingCost","Total profit",""]].sum()
# Out:
#       Unit_MakingCost  Total profit  Unit_MakingCost
# Year
# 2010        120335.72  2.415637e+08        120335.72
# 2011        116037.97  2.580650e+08        116037.97
# 2012        122580.87  2.756606e+08        122580.87
# 2013        126698.68  2.650466e+08        126698.68
# 2014        124757.69  2.567280e+08        124757.69
# 2015        137242.91  2.716082e+08        137242.91
# 2016        122275.12  2.539424e+08        122275.12
# 2017         67541.76  1.398906e+08         67541.76

# %%
df["Year"].value_counts()
df.groupby("Year")["Unit_MakingCost"].sum().plot.bar()
# Out:
# <Axes: xlabel='Year'>
